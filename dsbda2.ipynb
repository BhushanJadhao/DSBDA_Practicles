# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# %%
data=pd.read_csv("/content/sample_data/DataStudents.csv")
df=pd.DataFrame(data)
df
# Out:
#     RollNo       Name  Age Maths  Science  English Total Average
# 0        1     Anish    18    25       35       56   116    NaN
# 1        2  Aasawari    20    33       78       34   145    48.3
# 2        3    Aditya    11    90       33       22   145    48.3
# 3        4   Apoorva    22    45       88       56   189      63
# 4        5      Anil    12    66       43       88   197    65.7
# 5        6     Bablu    13  NaN        35       53   110    NaN
# 6        7    Chetan    12    56       66       78  NaN     66.7
# 7        8   Chinmay    14    56       36       68   160    53.3
# 8        9    Chitra    15    67       22       32   121    40.3
# 9       10      Diya    16    54       78       88   220    73.3
# 10      11    Deepak    34    33       44       71   148    49.3
# 11      12     Dilip    18    87       89       37   213    NaN
# 12      13      Esha    19    89       53       40   182    60.7
# 13      14    Fatima    17    34       45       78   157    52.3
# 14      15      Faiz    11    32       51       27   110    36.7
# 15      16    Gaurav    19    80       30       28   138      46
# 16      17    Hitesh    20  NaN        74       30  NaN     64.7
# 17      18      Isha    14    50       90       56   196    65.3
# 18      19     Ishan    16    40       42       89   171      57
# 19      20       Jay    18    48       72       90   210      70

# %%
df.describe()
# Out:
#          RollNo        Age    Science    English
# count  20.00000  20.000000  20.000000  20.000000
# mean   10.50000  16.950000  55.200000  56.050000
# std     5.91608   5.155222  22.018174  23.811707
# min     1.00000  11.000000  22.000000  22.000000
# 25%     5.75000  13.750000  35.750000  33.500000
# 50%    10.50000  16.500000  48.000000  56.000000
# 75%    15.25000  19.000000  75.000000  78.000000
# max    20.00000  34.000000  90.000000  90.000000

# %%
df.isnull().head(7)
# Out:
#    RollNo   Name    Age  Maths  Science  English  Total  Average
# 0   False  False  False  False    False    False  False    False
# 1   False  False  False  False    False    False  False    False
# 2   False  False  False  False    False    False  False    False
# 3   False  False  False  False    False    False  False    False
# 4   False  False  False  False    False    False  False    False
# 5   False  False  False  False    False    False  False    False
# 6   False  False  False  False    False    False  False    False

# %%
df.head(10)
# Out:
#    RollNo       Name  Age Maths  Science  English Total Average
# 0       1     Anish    18    25       35       56   116    NaN
# 1       2  Aasawari    20    33       78       34   145    48.3
# 2       3    Aditya    11    90       33       22   145    48.3
# 3       4   Apoorva    22    45       88       56   189      63
# 4       5      Anil    12    66       43       88   197    65.7
# 5       6     Bablu    13  NaN        35       53   110    NaN
# 6       7    Chetan    12    56       66       78  NaN     66.7
# 7       8   Chinmay    14    56       36       68   160    53.3
# 8       9    Chitra    15    67       22       32   121    40.3
# 9      10      Diya    16    54       78       88   220    73.3

# %%
df['Maths'] = df['Maths'].fillna(df['Maths'].mean())
df['Science'] = df['Science'].fillna(df['Science'].mean())
df['English'] = df['English'].fillna(df['English'].mean())
df['Total'] = df['Total'].fillna(df['Total'].mean())
df['Average'] = df['Average'].fillna(df['Average'].mean())
df.head(7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1691         try:
# -> 1692             x = float(x)
#    1693         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '2533904566NaN 56566754338789343280NaN 504048'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1695             try:
# -> 1696                 x = complex(x)
#    1697             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-fbf79b277cb5> in <cell line: 1>()
# ----> 1 df['Maths'] = df['Maths'].fillna(df['Maths'].mean())
#       2 df['Science'] = df['Science'].fillna(df['Science'].mean())
#       3 df['English'] = df['English'].fillna(df['English'].mean())
#       4 df['Total'] = df['Total'].fillna(df['Total'].mean())
#       5 df['Average'] = df['Average'].fillna(df['Average'].mean())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11554             **kwargs,
#   11555         ):
# > 11556             return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11557
#   11558         setattr(cls, "mean", mean)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in mean(self, axis, skipna, numeric_only, **kwargs)
#   11199         **kwargs,
#   11200     ) -> Series | float:
# > 11201         return self._stat_function(
#   11202             "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11156         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11157
# > 11158         return self._reduce(
#   11159             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4668                 )
#    4669             with np.errstate(all="ignore"):
# -> 4670                 return op(delegate, skipna=skipna, **kwds)
#    4671
#    4672     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      94             try:
#      95                 with np.errstate(invalid="ignore"):
# ---> 96                     return f(*args, **kwargs)
#      97             except ValueError as e:
#      98                 # we want to transform an object array
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     156                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157             else:
# --> 158                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     159
#     160             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     419             mask = isna(values)
#     420
# --> 421         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     422
#     423         if datetimelike:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     725
#     726     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     728
#     729     if axis is not None and getattr(the_sum, "ndim", False):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1697             except ValueError as err:
#    1698                 # e.g. "foo"
# -> 1699                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1700     return x
#    1701
#
# TypeError: Could not convert 2533904566NaN 56566754338789343280NaN 504048 to numeric
